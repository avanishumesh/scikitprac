# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mehmetisik/livecsv")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 99.3k/99.3k [00:00<00:00, 175kB/s]
# Extracting files...
# Path to dataset files: C:\Users\avani\.cache\kagglehub\datasets\mehmetisik\livecsv\versions\1

# %%
df = pd.read_csv('Live.csv')

# %%
df
# Out:
#                               status_id status_type status_published  \
# 0      246675545449582_1649696485147474       video   4/22/2018 6:00
# 1      246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2      246675545449582_1648730588577397       video   4/21/2018 6:17
# 3      246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4      246675545449582_1645700502213739       photo   4/18/2018 3:22
# ...                                 ...         ...              ...
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# ...

# %%
df.shape
# Out:
# (7050, 16)

# %%
df.tail(5)
# Out:
#                               status_id status_type status_published  \
# 7045  1050855161656896_1061863470556065       photo   9/24/2016 2:58
# 7046  1050855161656896_1061334757275603       photo  9/23/2016 11:19
# 7047  1050855161656896_1060126464063099       photo  9/21/2016 23:03
# 7048  1050855161656896_1058663487542730       photo   9/20/2016 0:43
# 7049  1050855161656896_1050858841656528       photo  9/10/2016 10:30
#
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 7045             89             0           0         89          0         0
# 7046             16             0           0         14          1         0
# 7047              2             0           0          1          1         0
# 7048            351            12          22        349          2         0
# 7049             17             0           0         17          0         0
#
#       num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
#chcecking for null

df.isnull().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
df.isna().sum()
# Out:
# status_id              0
# status_type            0
# status_published       0
# num_reactions          0
# num_comments           0
# num_shares             0
# num_likes              0
# num_loves              0
# num_wows               0
# num_hahas              0
# num_sads               0
# num_angrys             0
# Column1             7050
# Column2             7050
# Column3             7050
# Column4             7050
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
df.describe()#statistical analysis
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  Column1  Column2  \
# count  7050.000000  7050.000000  7050.000000  7050.000000      0.0      0.0
# mean      1.289362     0.696454     0.243688     0.113191      NaN      NaN
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("balasaibodanki/live-csv")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 138k/138k [00:00<00:00, 210kB/s]
# Extracting files...
# Path to dataset files: C:\Users\avani\.cache\kagglehub\datasets\balasaibodanki\live-csv\versions\1

# %%
len(df['status_id'].unique())
# Out:
# 6997

# %%
len(df['status_published'].unique())
# Out:
# 6913

# %%
len(df['status_type'].unique())
# Out:
# 4

# %%
df.drop(['status_id','status_published'],axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
#  10  Column1        0 non-null      float64
#  11  Column2        0 non-null      float64
#  12  Column3        0 non-null      float64
#  13  Column4        0 non-null      float64
# dtypes: float64(4), int64(9), object(1)
# memory usage: 771.2+ KB

# %%
X = df
y = df['status_type']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X['status_type'] = le.fit_transform(X['status_type'])
y = le.fit_transform(y)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   int64
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
#  10  Column1        0 non-null      float64
#  11  Column2        0 non-null      float64
#  12  Column3        0 non-null      float64
#  13  Column4        0 non-null      float64
# dtypes: float64(4), int64(10)
# memory usage: 771.2 KB

# %%
#feature Scaling

cols = X.columns

from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
X = ms.fit_transform(X)

# %%
X = pd.DataFrame(X,columns = cols)

# %%
X
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0        1.000000       0.112314      0.024393    0.076519   0.091720
# 1        0.333333       0.031847      0.000000    0.000000   0.031847
# 2        1.000000       0.048195      0.011243    0.016647   0.043312
# 3        0.333333       0.023567      0.000000    0.000000   0.023567
# 4        0.333333       0.045223      0.000000    0.000000   0.043312
# ...           ...            ...           ...         ...        ...
# 7045     0.333333       0.018896      0.000000    0.000000   0.018896
# 7046     0.333333       0.003397      0.000000    0.000000   0.002972
# 7047     0.333333       0.000425      0.000000    0.000000   0.000212
# 7048     0.333333       0.074522      0.000572    0.006425   0.074098
# 7049     0.333333       0.003609      0.000000    0.000000   0.003609
#
#       num_loves  num_wows  num_hahas  num_sads  num_angrys  Column1  Column2  \
# ...

# %%
#Model Creation

from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2,random_state = 0)
kmeans.fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 6
#       3 from sklearn.cluster import KMeans
#       5 kmeans = KMeans(n_clusters=2,random_state = 0)
# ----> 6 kmeans.fit(X)
#
# File c:\Users\avani\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\avani\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\cluster\_kmeans.py:1460, in KMeans.fit(self, X, y, sample_weight)
#    1432 @_fit_context(prefer_skip_nested_validation=True)
# ...

# %%
print(X.isnull().sum())
# Out:
# status_type         0
# num_reactions       0
# num_comments        0
# num_shares          0
# num_likes           0
# num_loves           0
# num_wows            0
# num_hahas           0
# num_sads            0
# num_angrys          0
# Column1          7050
# Column2          7050
# Column3          7050
# Column4          7050
# dtype: int64

# %%
X.drop(['Column1','Column2','Column3','Column4'],axis =1, inplace = True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   float64
#  1   num_reactions  7050 non-null   float64
#  2   num_comments   7050 non-null   float64
#  3   num_shares     7050 non-null   float64
#  4   num_likes      7050 non-null   float64
#  5   num_loves      7050 non-null   float64
#  6   num_wows       7050 non-null   float64
#  7   num_hahas      7050 non-null   float64
#  8   num_sads       7050 non-null   float64
#  9   num_angrys     7050 non-null   float64
# dtypes: float64(10)
# memory usage: 550.9 KB

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
#kmeans parameter check

kmeans.cluster_centers_
# Out:
# array([[9.54921576e-01, 6.46330441e-02, 2.67028654e-02, 2.93171709e-02,
#         5.71231462e-02, 4.71007076e-02, 8.18581889e-03, 9.65207685e-03,
#         8.04219428e-03, 7.19501847e-03],
#        [3.28506857e-01, 3.90710874e-02, 7.54854864e-04, 7.53667113e-04,
#         3.85438884e-02, 2.17448568e-03, 2.43721364e-03, 1.20039760e-03,
#         2.75348016e-03, 1.45313276e-03]])

# %%
kmeans.inertia_
# Out:
# 237.7572640441955

# %%
#Check model quality

labels = kmeans.labels_

correct_labels = sum(y==labels)
print('Result: %d out of %d samples are correctly labelled')
